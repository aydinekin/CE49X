# %%
"""
# Life Cycle Analysis (LCA) Tool Example

This script demonstrates the functionality of the LCA tool for analyzing environmental impacts 
of products throughout their life cycle.
"""

# %% [markdown]
# ## 1. Setup and Data Loading
#
# First, let's import the necessary modules and load our data.

# %%
import sys
sys.path.append('..')

import pandas as pd
import matplotlib.pyplot as plt
from src.data_input import DataInput
from src.calculations import LCACalculator
from src.visualization import LCAVisualizer

# %% [markdown]
# ### Load Product Data
# Load the sample product data from CSV file.

# %%
# Initialize data input handler
data_input = DataInput()

# Load product data
product_data = data_input.read_data('../data/raw/sample_data.csv')
print("Product Data Shape:", product_data.shape)
product_data.head()
# Out:
# Product Data Shape: (60, 14)
#   product_id           product_name life_cycle_stage material_type  \
# 0       P001    Reinforced Concrete    Manufacturing      Concrete
# 1       P001    Reinforced Concrete   Transportation      Concrete
# 2       P001    Reinforced Concrete      End-of-Life      Concrete
# 3       P002  Structural Steel Beam    Manufacturing         Steel
# 4       P002  Structural Steel Beam   Transportation         Steel
#
#    quantity_kg  energy_consumption_kwh  transport_distance_km transport_mode  \
# 0       2500.0                   120.0                     50          Truck
# 1       2500.0                    20.0                    100          Truck
# 2       2500.0                    50.0                     30          Truck
# 3        500.0                   300.0                    200          Truck
# 4        500.0                    40.0                    150          Truck
#
#    waste_generated_kg  recycling_rate  landfill_rate  incineration_rate  \
# 0               125.0             0.1           0.80               0.10
# 1                 0.0             0.0           0.00               0.00
# 2              2500.0             0.1           0.80               0.10
# 3                25.0             0.9           0.05               0.05
# 4                 0.0             0.0           0.00               0.00
#
#    carbon_footprint_kg_co2e  water_usage_liters
# 0                     350.0               150.0
# 1                      75.0                 0.0
# 2                     200.0                50.0
# 3                     450.0               200.0
# 4                     100.0                 0.0

# %% [markdown]
# ### Load Impact Factors
# Load the environmental impact factors from JSON file.

# %%
# Load impact factors
impact_factors = data_input.read_impact_factors('../data/raw/impact_factors.json')
print("Available Materials:", list(impact_factors.keys()))
print("\nImpact Factors for Steel:")
pd.DataFrame(impact_factors['steel'])
# Out:
# Available Materials: ['steel', 'aluminum', 'plastic', 'paper', 'concrete', 'wood', 'clay', 'glass', 'copper', 'mineral_wool', 'cement']
#
# Impact Factors for Steel:
#               manufacturing transportation disposal
# carbon_impact           1.8            0.5      0.1
# carbon_unit         kg CO2e        kg CO2e  kg CO2e
# energy_impact            20              5        1
# energy_unit              MJ             MJ       MJ
# water_impact            150             30       10
# water_unit                L              L        L

# %% [markdown]
# ## 2. Impact Calculations
#
# Calculate environmental impacts using the LCACalculator.

# %%
# Initialize calculator
calculator = LCACalculator(impact_factors_path='../data/raw/impact_factors.json')

# Calculate impacts
impacts = calculator.calculate_impacts(product_data)
print("Calculated Impacts Shape:", impacts.shape)
impacts.head()
# Out:
# Calculated Impacts Shape: (60, 14)
#   product_id           product_name life_cycle_stage material_type  \
# 0       P001    Reinforced Concrete    manufacturing      concrete
# 1       P001    Reinforced Concrete   transportation      concrete
# 2       P001    Reinforced Concrete      end-of-life      concrete
# 3       P002  Structural Steel Beam    manufacturing         steel
# 4       P002  Structural Steel Beam   transportation         steel
#
#    quantity_kg  energy_consumption_kwh  transport_distance_km  \
# 0       2500.0                   120.0                     50
# 1       2500.0                    20.0                    100
# 2       2500.0                    50.0                     30
# 3        500.0                   300.0                    200
# 4        500.0                    40.0                    150
#
#    waste_generated_kg  carbon_impact  energy_impact  water_impact  \
# 0               125.0          700.0         3870.0      150150.0
# 1                 0.0          150.0          770.0           0.0
# 2              2500.0          200.0           50.0          50.0
# 3                25.0         1350.0        10300.0       75200.0
# 4                 0.0          350.0         2540.0       15000.0
#
#    recycling_rate  landfill_rate  incineration_rate
# 0             0.1           0.80               0.10
# 1             0.0           0.00               0.00
# 2             0.1           0.80               0.10
# 3             0.9           0.05               0.05
# 4             0.0           0.00               0.00

# %% [markdown]
# ### Calculate Total Impacts
# Aggregate impacts by product.

# %%
# Calculate total impacts
total_impacts = calculator.calculate_total_impacts(impacts)
print("Total Impacts by Product:")
total_impacts
# Out:
# Total Impacts by Product:
#    product_id             product_name  carbon_impact  energy_impact  \
# 0        P001      Reinforced Concrete         1050.0         4690.0
# 1        P002    Structural Steel Beam         1850.0        12870.0
# 2        P003     Engineered Wood Beam          300.0         1205.0
# 3        P004               Clay Brick           11.0           72.0
# 4        P005              Glass Panel          800.0         3850.0
# 5        P006              Copper Wire          540.0         2585.0
# 6        P007        Aluminum Cladding          432.0          845.0
# 7        P008         Insulation Board          225.0          125.0
# 8        P009             Plastic Pipe          175.0           95.0
# 9        P010             Cement Block          158.0          408.0
# 10       P011              Steel Rebar          470.0         2800.0
# 11       P012            Wood Flooring          130.0          628.0
# 12       P013             Glass Window          640.0         3080.0
# 13       P014              Copper Pipe          432.0         2067.0
# 14       P015  Mineral Wool Insulation          140.0          100.0
# 15       P016           Concrete Block            6.3           86.0
# 16       P017           Clay Roof Tile            8.8           57.5
# 17       P018    Aluminum Window Frame           94.5          635.0
# 18       P019         Steel Roof Panel          376.0         2245.0
# 19       P020                Wood Stud           78.0          392.0
#
#     water_impact  waste_generated_kg
# 0       150200.0             2625.00
# 1        90230.0              525.00
# 2         8100.0              105.00
# 3          112.0                2.75
# 4        10115.0               52.50
# 5         5060.0               10.50
# 6         4872.0               21.00
# 7           48.0               15.75
# 8           35.0                5.25
# 9         2530.0               21.00
# 10       18160.0              105.00
# 11        4050.0               52.50
# 12        8092.0               42.00
# 13        4048.0                8.40
# 14          38.0               12.60
# 15         912.0               15.75
# 16          89.6                2.20
# 17        3654.0               15.75
# 18       14528.0               84.00
# 19        2430.0               31.50

# %% [markdown]
# ## 3. Visualization
#
# Create various visualizations using the LCAVisualizer.

# %% [markdown]
# ### Impact Breakdown by Material Type

# %%
visualizer = LCAVisualizer()

# Plot carbon impact breakdown by material type
fig = visualizer.plot_impact_breakdown(impacts, 'carbon_impact', 'material_type')
plt.show()

# %% [markdown]
# ### Life Cycle Impacts for a Specific Product

# %%
# Plot life cycle impacts for Product1
fig = visualizer.plot_life_cycle_impacts(impacts, 'P001')
plt.show()

# %% [markdown]
# ### Product Comparison

# %%
# Compare two products
fig = visualizer.plot_product_comparison(impacts, ['P001', 'P002'])
plt.show()

# %% [markdown]
# ### End-of-Life Management

# %%
# Plot end-of-life breakdown for Product1
fig = visualizer.plot_end_of_life_breakdown(impacts, 'P001')
plt.show()

# %% [markdown]
# ### Impact Category Correlations

# %%
# Plot impact correlations
fig = visualizer.plot_impact_correlation(impacts)
plt.show()

# %% [markdown]
# ## 4. Advanced Analysis
#
# Perform more advanced analysis using the calculator's features.

# %% [markdown]
# ### Normalize Impacts

# %%
# Normalize impacts for comparison
normalized_impacts = calculator.normalize_impacts(impacts)
print("Normalized Impacts:")
normalized_impacts.head()

# %% [markdown]
# ### Compare Alternatives

# %%
# Compare alternative products
comparison = calculator.compare_alternatives(impacts, ['P001', 'P002'])
print("Product Comparison:")
comparison
